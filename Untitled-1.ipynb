# %%
def mul(a,b):
    return a*b 
print(mul(5,3))
# Out:
# 15

# %%
person ={
    "name":"nijin",
    "age" : 38,
    "city":"tvm",
    "is_developer":True,

}
print(person["name"])
# Out:
# nijin

# %%
n = int(input("How many elements? "))
my_list = []
for i in range(n):
    element = input(f"Enter element {i+1}: ")
    my_list.append(element)
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 n = int(input("How many elements? "))
#       2 my_list = []
#       3 for i in range(n):
#       4     element = input(f"Enter element {i+1}: ")
#
# ValueError: invalid literal for int() with base 10: 'sin'

# %%
import math

def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        return "Error! Division by zero."
    return x / y
def pow(x,y):
    return math.pow(x,y)
def sqrt(x):
    return math.sqrt(x)
def sin(x):
    return math.sin(x)
def cos(x):
    return math.cos(math.radians(x))

choice = input("Enter choice : ")

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if choice == '+':
    print("Result:", add(num1, num2))
elif choice == '-':
    print("Result:", subtract(num1, num2))
elif choice == '*':
    print("Result:", multiply(num1, num2))
elif choice == '/':
    print("Result:", divide(num1, num2))
elif choice == 'sin':
    print("Result:",sin(num1))
elif choice == 'sqrt':
    print("Result:",sqrt(num1))
elif choice == 'power':
    print("Result:",pow(num1,num2))
else:
    print("Invalid input")
# Out:
# Result: 3.0

# %%
words = input("Enter words separated by space: ").split()
filtered = [w for w in words if len(w) > 5]

print("Original list:", words)
print("Filtered list (length > 5):", filtered)
# Out:
# Original list: ['2', '3', '4', '5', '6', '7']
# Filtered list (length > 5): []

# %%
numbers = list(map(int, input("Enter numbers separated by space: ").split()))

evens = [x for x in numbers if x % 2 == 0]

print("Original list:", numbers)
print("Filtered list (evens):", evens)
# Out:
# Original list: [1, 2, 3, 4, 5, 6, 7]
# Filtered list (evens): [2, 4, 6]

# %%
fruits = ["apple", "banana", "cherry", "blueberry"]

filtered = [f for f in fruits if "b" in f]
print(filtered)
# Out:
# ['banana', 'blueberry']
