# %%
print("hello world")
# Out:
# hello world

# %%
name="NIJIN"
print("hello ,"+name)
# Out:
# hello ,NIJIN

# %%
age=25
year = 2025
height=5.25
collage="saintgits"
temperature=298
print(f"My name is {name}. I am {age} years old")
print(f"My height is {height}.Temperature is {temperature}")
print(f"I am studying in {collage} collage of engineering.")
# Out:
# My name is NIJIN. I am 25 years old
# My height is 5.25.Temperature is 298
# I am studying in saintgits collage of engineering

# %%
n=20
m=21
sum=n+m
sub=n-m
div=n//m
print(sum)
print(sub)
print(div)
# Out:
# 41
# -1
# 0

# %%
age=36
if age>=50:
    print("uncle")
elif (30<age<50) :
    print("broooo")
elif (age<30):
    print("broo")
else:
    print("child")
# Out:
# broooo

# %%
for i in range (10):
    print(i)

# %%
n = int(input("How many elements? "))
my_list = []
for i in range(n):
    element = input(f"Enter element {i+1}: ")
    my_list.append(element)
print(my_list)
